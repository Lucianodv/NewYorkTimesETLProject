# %% [markdown]
# # **PRIMERA PARTE**

# %% [markdown]
# ##IMPORTS - VARIABLES - URL

# %% [markdown]
# ### En esta primera entrega de "Extracción de datos" utilizaremos la api del New York Times, utilizaremos dos endpoints:
# ### 1. Nos va devolver las noticias mas populares del mundo
# ### 2. Nos devolvera por un rango de mes y año todos los articulos publicados mundialmente.

# %%
# !pip install -q fastparquet
# !pip install psycopg[binary]
# !pip install sqlalchemy

#importamos librerias
import os
import configparser
from sqlalchemy import create_engine
from sqlalchemy import MetaData
from datetime import datetime, timedelta, date

import requests
import pandas as pd
import sqlalchemy as sa
# Out:
# Requirement already satisfied: psycopg[binary] in /usr/local/lib/python3.10/dist-packages (3.1.14)
# Requirement already satisfied: typing-extensions>=4.1 in /usr/local/lib/python3.10/dist-packages (from psycopg[binary]) (4.5.0)
# Requirement already satisfied: psycopg-binary==3.1.14 in /usr/local/lib/python3.10/dist-packages (from psycopg[binary]) (3.1.14)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (2.0.23)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (4.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (3.0.1)

# %%
#VARIABLES
config = configparser.ConfigParser()
config.read("config.ini")
API_KEY = config["keys"]["API_KEY"]
'''
Obtengo la fecha actual y las separo para poder mandarla por parametro a la url
al hacerlo de esta manera se va actualizar automaticamente y evitar pasarlo en duro.
'''
today = datetime.now()

Year = str(today.year)
Month = str(today.month)

#URL
urlBase = 'https://api.nytimes.com/svc/'

urlMostPopular = urlBase+'topstories/v2/world.json?api-key='
urlYearMonth = urlBase + f"archive/v1/{Year}/{Month}.json?api-key="

# %%
#RESPUESTAS

#ARTICULOS MAS POPULARES
r_popular_news =  requests.get(urlMostPopular+API_KEY).json()

#HISTORICO DE ARTICULOS POR MES
r_nyt_month =  requests.get(urlYearMonth+API_KEY).json()

# %% [markdown]
# ## **FUNCION PARA DEVOLVER LAS NOTICIAS MAS POPULARES**

# %% [markdown]
# ### Una vez analizado la respuesta JSON creamos una funcion que en este caso llamamos getPopularNews, esta funcion consta de varios pasos:
# ### 1ero: Creamos un DataFrame con las columnas que vamos a utilizar.
# ### 2do: con un FOR levantamos la informacion que creemos importante y la **guardamos** en una variable. (Corregimos valores en este caso fechas)
# ### 3ero: Unimos la informacion de las variables y unimos con las columnas, al final retornamos el dataframe ya listo.

# %%
def getPopularNews(r_popular_news):

  #Creacion del DataFrame con las columnas
  df_PopularNews  = pd.DataFrame(columns=['section', 'title', 'abstract', 'byline', 'item_type',
                                          'created_date', 'published_date', 'updated_date', 'link'])

  #Levantar con un FOR la informacion
  for note in r_popular_news['results']:
    #Esto podria ingresar en la parte de limpieza ya que existen 'tipos multimedia' que son videos shorts como youtube y preferi sacarlo ahora
    if note['item_type'] == 'Article':
      section = note['section']
      title = note['title']
      abstract = note['abstract']
      link = note['url']
      byline = note['section']
      item_type = note['item_type']
      created_date = note['created_date']
      published_date = note['published_date']
      updated_date = note['updated_date']

      #Correcion de Fechas
      created_date = str(created_date).split("T")[0]
      published_date = str(published_date).split("T")[0]
      updated_date = str(updated_date).split("T")[0]

      #Creamos un DataFrame con los datos de la nota
      df_note = pd.DataFrame({'section': section,
                               'title': title,
                               'abstract': abstract,
                               'byline': byline,
                               'item_type': item_type,
                               'created_date': created_date,
                               'published_date': published_date,
                               'updated_date': updated_date,
                               'link': link}, index=[0])

      #Concatenamos el DataFrame con el DataFrame original
      df_PopularNews = pd.concat([df_PopularNews, df_note], ignore_index=True)

  return df_PopularNews

# %%
dfPopularNews  = getPopularNews(r_popular_news)
dfPopularNews
# Out:
#      section                                              title  \
# 0      world  Ukrainians in Germany Weigh Wrenching Choice: ...
# 1      world  Maduro, Under Pressure, Holds Vote to Annex Te...
# 2      world  Israeli Mothers Knew Their Sons Would Serve. B...
# 3      world  Explosion at Catholic Mass in Philippines Kill...
# 4      world  Deadly Paris Knife Attack Revives Terrorism Co...
# 5      world  Tracing the Deep Roots of Ireland’s Support fo...
# 6      world  Intelligence Errors Prompt Scrutiny of Israeli...
# 7      world  Unusual Names Can Complicate Life in Japan. No...
# 8      world  After Watching 10 Migrants Die at Sea, He Now ...
# 9      world  Ex-Chilean Army Officer Is Expelled From U.S. ...
# 10     world  Crossing the Dnipro: What a Ukrainian Military...
# 11     world  He Won Election to Canada’s Parliament. Did Ch...
# 12     world  Israelis Are Angry at Netanyahu, but Chances o...
# 13     world  U.S. Is Pressing Israel and Hamas to Resume Ta...
# 14     world  With Big State Victories, Modi Expands His Dom...
# 15     world  Munich Airport Resumes Operations After Major ...
# 16     world  Released hostages give Tel Aviv protesters hop...
# 17     world  Harris Says U.S. Strongly Opposes ‘Forced Relo...
# 18     world  Powerful Earthquake Strikes Eastern Philippine...
# 19     world  Israel Orders Evacuations Amid ‘Intense’ Attac...
# 20  briefing                           Why Don’t We Dance More?
# 21     world  Canada Fast-Tracks 10.4 Billion Dollar Militar...
# 22   climate  22 Countries Pledge to Triple Nuclear Capacity...
# 23   climate  Biden Administration Unleashes Powerful Regula...
# 24     world      Southern Gaza girds for the war’s next phase.
# 25     world  World Food Program Staff Confronts Cindy McCai...
# 26     world  A protester self-immolates outside the Israeli...
# 27     world  Henri Lopes, 86, Who Straddled Literature and ...
# 28     world  With the End of the Cease-Fire, Concern Grows ...
# 29     world  Freed Palestinians Were Mostly Young and Not C...
# 30     world  Israel Resumes Offensive in Gaza Strip After T...
# 31     world  At P.S.G., a Coach’s Vision Collides With a St...
# 32     world  Some Freed Hostages Are Only Now Learning of L...
# 33     world  Blinken Says Hamas Is Responsible for Resumpti...
# 34     world  Alleged Plot to Kill Sikh Separatist Highlight...
# 35     world  Israel’s Next Aim Is Southern Gaza. U.S. Urges...
#
#                                              abstract    byline item_type  \
# 0   As refugees, they were welcomed with safety, s...     world   Article
# 1   The Venezuelan president is holding a referend...     world   Article
# 2   Many mothers are grappling with anxiety as the...     world   Article
# 3   The blast, which was claimed by the Islamic St...     world   Article
# 4   The authorities said the suspect had serious p...     world   Article
# 5   In a country with its own history of a seeming...     world   Article
# 6   The Israeli media and The New York Times publi...     world   Article
# 7   As such names have increased, so has media att...     world   Article
# 8   Witness to a tragedy on a boat to Spain, Moust...     world   Article
# 9   Pedro Barrientos, 74, was charged in the kidna...     world   Article
# 10  Ukrainian troops have taken positions on the e...     world   Article
# 11  A Canadian rapporteur said there was “well-gro...     world   Article
# 12  Many hold Prime Minister Benjamin Netanyahu re...     world   Article
# 13  John Kirby said that Hamas was to blame for th...     world   Article
# 14  Results of voting for the governments of four ...     world   Article
# 15  Heavy snow in Southern Germany on Saturday pro...     world   Article
# 16  Hostages who were recently released thanked de...     world   Article
# 17  The vice president’s statement came after a da...     world   Article
# 18  The authorities in Japan and the Philippines l...     world   Article
# 19  Beleaguered Gazans, having fled the territory’...     world   Article
# 20  Dancing offers an opportunity to use our bodie...  briefing   Article
# 21  To avoid a seemingly endless process, the gove...     world   Article
# 22  The group, including Britain, France and the U...   climate   Article
# 23  Its new estimate of the economic impact of cli...   climate   Article
# 24                                                        world   Article
# 25  Staff members accused Ms. McCain, the W.F.P.’s...     world   Article
# 26  A security guard tried to intervene but was un...     world   Article
# 27  His lauded fiction satirized abuses of power i...     world   Article
# 28  Going without medicines, proper nutrition and ...     world   Article
# 29  Israel has released a total of 240 Palestinian...     world   Article
# 30  Talks on extending a weeklong cease-fire broke...     world   Article
# 31  The system may be the center of the modern soc...     world   Article
# 32  More than any of them are now learning for the...     world   Article
# 33  The U.S. secretary of state said he also belie...     world   Article
# 34  The charges are rooted in a decades-old disput...     world   Article
# 35  American officials are making clear to Israel ...     world   Article
#
#    created_date published_date updated_date  \
# 0    2023-12-03     2023-12-03   2023-12-03
# 1    2023-12-03     2023-12-03   2023-12-03
# 2    2023-12-03     2023-12-03   2023-12-03
# 3    2023-12-02     2023-12-02   2023-12-03
# 4    2023-12-02     2023-12-02   2023-12-03
# 5    2023-12-02     2023-12-02   2023-12-03
# 6    2023-12-02     2023-12-02   2023-12-03
# 7    2023-12-01     2023-12-01   2023-12-02
# 8    2023-12-02     2023-12-02   2023-12-03
# 9    2023-12-02     2023-12-02   2023-12-03
# 10   2023-12-02     2023-12-02   2023-12-02
# 11   2023-12-02     2023-12-02   2023-12-02
# 12   2023-12-02     2023-12-02   2023-12-03
# 13   2023-12-03     2023-12-03   2023-12-03
# 14   2023-12-03     2023-12-03   2023-12-03
# 15   2023-12-03     2023-12-03   2023-12-03
# 16   2023-12-02     2023-12-02   2023-12-03
# 17   2023-12-02     2023-12-02   2023-12-02
# 18   2023-12-02     2023-12-02   2023-12-02
# 19   2023-12-02     2023-12-02   2023-12-03
# 20   2023-12-02     2023-12-02   2023-12-02
# 21   2023-12-02     2023-12-02   2023-12-02
# 22   2023-12-02     2023-12-02   2023-12-02
# 23   2023-12-02     2023-12-02   2023-12-02
# 24   2023-12-02     2023-12-02   2023-12-02
# 25   2023-12-01     2023-12-01   2023-12-01
# 26   2023-12-01     2023-12-01   2023-12-02
# 27   2023-12-01     2023-12-01   2023-12-03
# 28   2023-12-01     2023-12-01   2023-12-02
# 29   2023-12-01     2023-12-01   2023-12-03
# 30   2023-12-01     2023-12-01   2023-12-02
# 31   2023-12-01     2023-12-01   2023-12-02
# 32   2023-12-01     2023-12-01   2023-12-02
# 33   2023-12-01     2023-12-01   2023-12-01
# 34   2023-12-01     2023-12-01   2023-12-02
# 35   2023-12-01     2023-12-01   2023-12-02
#
#                                                  link
# 0   https://www.nytimes.com/2023/12/03/world/europ...
# 1   https://www.nytimes.com/2023/12/03/world/ameri...
# 2   https://www.nytimes.com/2023/12/03/world/middl...
# 3   https://www.nytimes.com/2023/12/02/world/asia/...
# 4   https://www.nytimes.com/2023/12/02/world/europ...
# 5   https://www.nytimes.com/2023/12/02/world/europ...
# 6   https://www.nytimes.com/2023/12/02/world/middl...
# 7   https://www.nytimes.com/2023/12/01/world/asia/...
# 8   https://www.nytimes.com/2023/12/02/world/afric...
# 9   https://www.nytimes.com/2023/12/02/world/ameri...
# 10  https://www.nytimes.com/2023/12/02/world/europ...
# 11  https://www.nytimes.com/2023/12/02/world/ameri...
# 12  https://www.nytimes.com/2023/12/02/world/middl...
# 13  https://www.nytimes.com/2023/12/03/world/middl...
# 14  https://www.nytimes.com/2023/12/03/world/asia/...
# 15  https://www.nytimes.com/2023/12/03/world/europ...
# 16  https://www.nytimes.com/2023/12/02/world/middl...
# 17  https://www.nytimes.com/2023/12/02/world/middl...
# 18  https://www.nytimes.com/2023/12/02/world/asia/...
# 19  https://www.nytimes.com/2023/12/02/world/middl...
# 20  https://www.nytimes.com/2023/12/02/briefing/wh...
# 21  https://www.nytimes.com/2023/12/02/world/ameri...
# 22  https://www.nytimes.com/2023/12/02/climate/cop...
# 23  https://www.nytimes.com/2023/12/02/climate/bid...
# 24  https://www.nytimes.com/2023/12/02/world/middl...
# 25  https://www.nytimes.com/2023/12/01/world/middl...
# 26  https://www.nytimes.com/2023/11/30/world/middl...
# 27  https://www.nytimes.com/2023/12/01/world/afric...
# 28  https://www.nytimes.com/2023/12/01/world/middl...
# 29  https://www.nytimes.com/2023/12/01/world/middl...
# 30  https://www.nytimes.com/2023/12/01/world/middl...
# 31  https://www.nytimes.com/2023/12/01/world/europ...
# 32  https://www.nytimes.com/2023/12/01/world/middl...
# 33  https://www.nytimes.com/2023/11/30/world/middl...
# 34  https://www.nytimes.com/2023/12/01/world/asia/...
# 35  https://www.nytimes.com/2023/12/01/world/middl...

# %% [markdown]
# ## **FUNCION PARA DEVOLVER UN HISTORICO DE NOTICIAS ACTUALIZADAS POR MES Y AÑO**

# %%
# FUNCION DE ARTICULOS HISTORICOS POR MES

def getHistoryNews(r_nyt_month):

  df_articles_month = pd.DataFrame(columns=['section', 'title', 'abstract', 'lead_paragraph', 'byline', 'document_type',
                                          'pub_date', 'total_word_count', 'web_url', 'year', 'month'])
  for note in r_nyt_month['response']['docs']:
    #Esto podria ingresar en la parte de limpieza ya que existen 'tipos multimedia' que son videos shorts como youtube y preferi sacarlo ahora
    if note['document_type'] == 'article':

      headline = note['headline']['main']
      abstrsact =  note['abstract']
      web_url = note['web_url']
      lead_paragraph = r_nyt_month['response']['docs'][0]['lead_paragraph']
      byline =  note['byline']['original']
      document_type = note['document_type']
      word_count =  note['word_count']
      pub_date =  note['pub_date']
      section_name = note['section_name']

      pub_date = str(pub_date).split("T")[0]

      # Creamos un DataFrame con los datos de la nota
      df_note = pd.DataFrame({'section': section_name,
                               'title': headline,
                               'abstract': abstrsact,
                               'lead_paragraph': lead_paragraph,
                               'byline': byline,
                               'document_type': document_type,
                               'pub_date': pub_date,
                               'total_word_count': word_count,
                               'web_url' : web_url}, index=[0])

      #Concatenamos el DataFrame con el DataFrame original
      df_articles_month = pd.concat([df_articles_month, df_note], ignore_index=True)

  # Defino la variable df
  df = df_articles_month

  # Convierto la columna pub_date al tipo datetimelike porque antes era str
  df['pub_date'] = pd.to_datetime(df['pub_date'], format='%Y-%m-%d')


  # Creo las nuevas columnas
  df['year'] = df['pub_date'].dt.year
  df['month'] = df['pub_date'].dt.month
  #Transformo fechas
  df["year"] = pd.to_datetime(df["year"], format="%Y")
  df["year"] = df["year"].dt.strftime("%Y")
  df["pub_date"] = df["pub_date"].dt.strftime("%Y-%m-%d")
  #df["year"] = datetime.datetime.strptime(df['year'], '%Y')










  df = df_articles_month

  return df_articles_month

# %%
df_articles_month = getHistoryNews(r_nyt_month)
df_articles_month
# Out:
#           section                                              title  \
# 0         Opinion   Donald Trump Still Wants to Kill Obamacare. Why?
# 1            U.S.  6 Former Jail Officers Charged in Death of Wes...
# 2           World  Israel Knew Hamas’s Attack Plan More Than a Ye...
# 3    Business Day                  Judge Halts TikTok Ban in Montana
# 4            U.S.  Kissinger Had the Ear of Presidents. He Had Th...
# ..            ...                                                ...
# 313       Climate  The Climate Summit Embraces A.I., With Reserva...
# 314      New York  5 Dead, Including Suspect, and 2 Officers Woun...
# 315          Food                This Chicken Should Be in Every Pot
# 316       Opinion           Sharp Views on Dating and Marriage Today
# 317          Arts  Geordie Walker, Guitarist for Killing Joke, Di...
#
#                                               abstract  \
# 0      Is this really about policy, or is it personal?
# 1    Prosecutors said the former corrections office...
# 2    A blueprint reviewed by The Times laid out the...
# 3    TikTok, which is owned by the Chinese company ...
# 4    In his decades in politics, the statesman advi...
# ..                                                 ...
# 313  The idea of using artificial intelligence to f...
# 314  The attack occurred early Sunday morning at a ...
# 315  Warm spices, sweet root vegetables, savory chi...
# 316  Readers discuss a guest essay about why many w...
# 317  He helped define the look as well as the sound...
#
#                                         lead_paragraph  \
# 0    Donald Trump hasn’t talked much about policy i...
# 1    Donald Trump hasn’t talked much about policy i...
# 2    Donald Trump hasn’t talked much about policy i...
# 3    Donald Trump hasn’t talked much about policy i...
# 4    Donald Trump hasn’t talked much about policy i...
# ..                                                 ...
# 313  Donald Trump hasn’t talked much about policy i...
# 314  Donald Trump hasn’t talked much about policy i...
# 315  Donald Trump hasn’t talked much about policy i...
# 316  Donald Trump hasn’t talked much about policy i...
# 317  Donald Trump hasn’t talked much about policy i...
#
#                                   byline document_type    pub_date  \
# 0                        By Paul Krugman       article  2023-12-01
# 1                       By Jesus Jiménez       article  2023-12-01
# 2      By Ronen Bergman and Adam Goldman       article  2023-12-01
# 3                    By Sapna Maheshwari       article  2023-12-01
# 4    By Erica L. Green and Kitty Bennett       article  2023-12-01
# ..                                   ...           ...         ...
# 313                    By Jim Tankersley       article  2023-12-03
# 314                       By Emma Bubola       article  2023-12-03
# 315                        By Sam Sifton       article  2023-12-03
# 316                                            article  2023-12-03
# 317                     By Alex Williams       article  2023-12-03
#
#     total_word_count                                            web_url  year  \
# 0                880  https://www.nytimes.com/2023/11/30/opinion/tru...  2023
# 1                673  https://www.nytimes.com/2023/11/30/us/west-vir...  2023
# 2               1582  https://www.nytimes.com/2023/11/30/world/middl...  2023
# 3               1030  https://www.nytimes.com/2023/11/30/business/ti...  2023
# 4                962  https://www.nytimes.com/2023/11/30/us/politics...  2023
# ..               ...                                                ...   ...
# 313              855  https://www.nytimes.com/2023/12/03/climate/art...  2023
# 314              357  https://www.nytimes.com/2023/12/03/nyregion/st...  2023
# 315              739  https://www.nytimes.com/2023/12/03/dining/this...  2023
# 316             1247  https://www.nytimes.com/2023/12/03/opinion/dat...  2023
# 317              841  https://www.nytimes.com/2023/12/03/arts/music/...  2023
#
#      month
# 0       12
# 1       12
# 2       12
# 3       12
# 4       12
# ..     ...
# 313     12
# 314     12
# 315     12
# 316     12
# 317     12
#
# [318 rows x 11 columns]

# %% [markdown]
# # **SEGUNDA PARTE ALMACENAMIENTO**

# %% [markdown]
# ### Esta primera particion la voy a realizar sobre el DF de las noticias mas populares, de tal manera que me queden separadas por categoria del articulo ya sea noticias de clima, deporte, mundo etc.

# %%
dfPopularNews.to_parquet(
    "datalake/bronze/popular_news_db/popular_news_by_line",
    partition_cols=["byline"],
    engine="fastparquet",
    )

# %% [markdown]
# ### La segunda paraticion la voy a realizar sobre el DF de todas las noticias del New york times, de una manera mensual y anual, para en caso de ser necesario poder revisar las noticias un mes y año especifico.

# %% [markdown]
# ### Decidi particionarlo de esta manera ya que si lo automatizamos y se corre el script diariamente no tendriamos duplicados y podriamos generar una base con dividida por mes y año.

# %%
df_articles_month.to_parquet(
    "datalake/bronze/all_news_db/all_news_by_date",
    partition_cols=["year", "month"],
    engine="fastparquet",
    )

# %% [markdown]
# # **TERCER PARTE**

# %% [markdown]
# ### En la anterior entrega ya habia realizado transformacion de datos ejemplo: transformacion de fechas, agregado de columnas mes y año separadas para poder particionarlo de una mejor manera y a la vez me sirve en un futuro para hacer consultas SQL y filtrar por esa columnas

# %% [markdown]
# ### Ahora vamos a revisar que ninguno de los DF contenga duplicados y algunas transformaciones de fechas antes de enviarlas a la base

# %%
#TRANSFORMACIONES DE FECHAS
dfPopularNews['created_date'] = pd.to_datetime(dfPopularNews['created_date'])
dfPopularNews['published_date'] = pd.to_datetime(dfPopularNews['published_date'])
dfPopularNews['updated_date'] = pd.to_datetime(dfPopularNews['updated_date'])

#cambie este formato a object ya que para enviarlo a la base de datos es mas facil y al ser solo el año se puede manipular mejor.
df_articles_month['year'] = df_articles_month['year'].astype('object')

# %%
#Se podria hacer en una linea directamente pero cree esta funcion para en un futuro caso si hay mas de un df solamente pasarle el nombre
#Lo que hace basicamente primero es averiguar con duplicated() si existe alguno y luego te retorna el index del duplicado

def find_duplicates(df):
    duplicated_rows = df.duplicated()
    return duplicated_rows.index[duplicated_rows]

# %%
df_duplicated_rows = find_duplicates(df_articles_month)
df_duplicated_rows
# Out:
# Int64Index([], dtype='int64')

# %%
df_duplicated_rows = find_duplicates(dfPopularNews)
df_duplicated_rows
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# ### Me conecto a la base de datos

# %%
# Leemos archivo ini
config = configparser.ConfigParser()
config.read('config.ini')

# Extract connection parameters
section = 'postgres'
host = config[section]['host']
port = config[section]['port']
db = config[section]['db']
user = config[section]['user']
pwd = config[section]['pwd']



def connect_to_postgres_db(config_file_path="config.ini", section="postgres"):
 global engine
 global connection
 conn_string = f"postgresql://{user}:{pwd}@{host}:{port}/{db}?sslmode-require"
 engine = create_engine(conn_string)
 connection = engine.connect()

connect_to_postgres_db(config_file_path="config.ini", section="postgres")

# %% [markdown]
# ## Cree las tablas de una manera que me parecio interesante ya que con el if puede saber si existen o no dependiendo el mensaje de respuesta. Se podria mejorar en una funcion. Pero para tenerl claro visualmente ahora me parece correcto y funcional.

# %%
#CREAMOS TABLA ARTICULOS POR MES

# Chequeamos si la tabla existe
if not sa.inspect(engine).has_table("LucianoVenialgo_ArticulosPorMes"):
    # si la tabla no existe, la creamos
    metadata = sa.MetaData()
    table = sa.Table(
        "LucianoVenialgo_ArticulosPorMes",
        metadata,
        sa.Column("section", sa.VARCHAR(200)),
        sa.Column("title", sa.VARCHAR(200)),
        sa.Column("abstract", sa.VARCHAR(1000)),
        sa.Column("lead_paragraph", sa.VARCHAR(1000)),
        sa.Column("byline", sa.VARCHAR(200)),
        sa.Column("document_type", sa.VARCHAR(200)),
        sa.Column("pub_date", sa.VARCHAR(200)),
        sa.Column("total_word_count", sa.Integer),
        sa.Column("web_url", sa.VARCHAR(200)),
        sa.Column("year", sa.VARCHAR(200)),
        sa.Column("month", sa.Integer),
    )

    table.create(engine)
    print("Table 'LucianoVenialgo_ArticulosPorMes' created successfully.")
else:
    # Si ya existe devolvemos este mensaje
    print("Table 'LucianoVenialgo_ArticulosPorMes' already exists.")
# Out:
# Table 'LucianoVenialgo_ArticulosPorMes' created successfully.

# %%
#CREAMOS TABLA ARTICULOS MAS POPULARES

# Chequeamos si la tabla existe
if not sa.inspect(engine).has_table("LucianoVenialgo_ArticulosPopulares"):
    # si la tabla no existe, la creamos
    metadata = sa.MetaData()
    table = sa.Table(
        "LucianoVenialgo_ArticulosPopulares",
        metadata,
        sa.Column("section", sa.VARCHAR(200)),
        sa.Column("title", sa.VARCHAR(200)),
        sa.Column("abstract", sa.VARCHAR(1000)),
        sa.Column("byline", sa.VARCHAR(200)),
        sa.Column("item_type", sa.VARCHAR(200)),
        sa.Column("created_date", sa.DATE),
        sa.Column("published_date", sa.DATE),
        sa.Column("updated_date", sa.DATE),
        sa.Column("link", sa.VARCHAR(200)),
    )

    table.create(engine)
    print("Table 'LucianoVenialgo_ArticulosPopulares' created successfully.")
else:
    # Si la tabla existe devolvemos este mensaje
    print("Table 'LucianoVenialgo_ArticulosPopulares' already exists.")
# Out:
# Table 'LucianoVenialgo_ArticulosPopulares' created successfully.

# %%
#Enviamos el df a la base de postgres
df_articles_month.to_sql(
    name="LucianoVenialgo_ArticulosPorMes",
    con=engine,
    if_exists="append",
    index=False,
    method='multi',

)
# Out:
# 318

# %%
dfPopularNews.to_sql(
    name="LucianoVenialgo_ArticulosPopulares",
    con=engine,
    if_exists="append",
    index=False,
    method='multi',

)
# Out:
# 36
